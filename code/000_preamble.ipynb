# %% [markdown]
# # Required Packages Installation
#
# The following stata code will uninstall any previous version prior to re-installing the user-written stata packages ```reghdfe``` and ```specurve```.

# %%
# %%capture
import stata_setup, os
if os.name == 'nt':
    stata_setup.config('C:/Program Files/Stata17/','mp')
else:
    stata_setup.config('/usr/local/stata17','mp')

# %% [markdown]
# ### reghdfe, ivreghdfe, ppmlhdfe | Models with Many Levels of Fixed Effects
# Source Code: [https://scorreia.com/software/](https://scorreia.com/software/)

# %%
# %%stata -qui
# * Install ftools (remove program if it existed previously)
# cap ado uninstall ftools
# net install ftools, from("https://raw.githubusercontent.com/sergiocorreia/ftools/master/src/")
#
# * Install reghdfe 6.x (remove program if it existed previously)
# cap ado uninstall reghdfe
# net install reghdfe, from("https://raw.githubusercontent.com/sergiocorreia/reghdfe/master/src/")
#
# * Install parallel, if using the parallel() option; don't install from SSC
# cap ado uninstall parallel
# net install parallel, from(https://raw.github.com/gvegayon/parallel/stable/) replace
# mata mata mlib index
#
# * Install ivreghdfe (remove program if it existed previously)
# cap ado uninstall ivreghdfe
# cap ssc install ivreg2 // Install ivreg2, the core package
# net install ivreghdfe, from(https://raw.githubusercontent.com/sergiocorreia/ivreghdfe/master/src/)
#
# * Install ppmlhdfe
# cap ado uninstall ppmlhdfe
# net install ppmlhdfe, from("https://raw.githubusercontent.com/sergiocorreia/ppmlhdfe/master/src/")

# %% [markdown]
# ### specurve | Specification Curve Analysis
# Source Code: [https://github.com/mgao6767/specurve](https://github.com/mgao6767/specurve)

# %%
# %%stata -qui
# * Install specurve
# net install specurve, from("https://raw.githubusercontent.com/mgao6767/specurve/master") replace

# %% [markdown]
# ### loocv | Leave-One-Out Regression I
# Source Code: [http://fmwww.bc.edu/repec/bocode/l/loocv.ado](http://fmwww.bc.edu/repec/bocode/l/loocv.ado)

# %%
# %%stata -qui
# ssc install loocv

# %% [markdown]
# ### cv_regress | Leave-One-Out Regression II
# Source Code: [https://github.com/friosavila/stpackages/tree/main/cv_regress](https://github.com/friosavila/stpackages/tree/main/cv_regress)

# %%
# %%stata -qui
# ssc install cv_regress

# %% [markdown]
# ### crossfold | _k_-Fold Cross-Validation
# Source Code: [https://ideas.repec.org/c/boc/bocode/s457426.html](https://ideas.repec.org/c/boc/bocode/s457426.html)

# %%
# %%stata -qui
# ssc install crossfold

# %% [markdown]
# ### Stata Schemepack
# Source Code: [https://github.com/asjadnaqvi/stata-schemepack](https://github.com/asjadnaqvi/stata-schemepack)

# %%
# %%stata -qui
# net install schemepack, from("https://raw.githubusercontent.com/asjadnaqvi/stata-schemepack/main/installation/") replace

# %% [markdown]
# ## estout | Making Regression Tables in Stata
# Source Code: [https://github.com/benjann/estout](https://github.com/benjann/estout)

# %%
# %%stata -qui
# net install estout, from(https://raw.githubusercontent.com/benjann/estout/master/) replace

# %% [markdown]
# # Data
#
# ||   |
# |-|-|
# |<img src="../figures/cover.png" width="140">| Rodriguez, Belicia, Kim P. Huynh,<br> David Tomás Jacho-Chávez, and<br> Leonardo Sánchez-Aragón, (2024),<br> "<em>Abstract Readability: Evidence from Top-5 Economics Journals</em>,"<br> <strong>Economics Letters</strong>, 111541.<br> - [Manuscript](../paper/Rodriguez_et_al_econ_letters_2024.pdf)<br> - [Supplemental Materials](../paper/Rodriguez_et_al_2024_supp_material.pdf)<br>- [GitHub Repository](https://github.com/lfsanche/econ_letters)|

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 150)
import pyreadstat

# Load the Stata dataset
datos, meta = pyreadstat.read_dta("../data/data.dta")

# Create a DataFrame from the variable names and labels
var_labels = pd.DataFrame({
    "Variable Name": meta.column_names,
    "Variable Label": meta.column_labels
})

# Print the DataFrame
var_labels
# Out:
#                        Variable Name  \
# 0                              title
# 1                            idpaper
# 2                            journal
# 3                        journal_num
# 4                               year
# 5                              month
# 6                             volume
# 7                              issue
# 8                           jelcodes
# 9                           keywords
# 10                          abstract
# 11                        start_page
# 12                          end_page
# 13                         num_words
# 14                 num_words_90_flag
# 15                          idauthor
# 16                            author
# 17                        prop_women
# 18                       num_authors
# 19                 gender_group_type
# 20                 sole_or_coauthors
# 21                         num_pages
# 22                   num_pages_dmean
# 23        flesch_kincaid_grade_level
# 24    log_flesch_kincaid_grade_level
# 25       flesch_kincaid_reading_ease
# 26   log_flesch_kincaid_reading_ease
# 27                        dale_chall
# 28                    log_dale_chall
# 29                coleman_liau_index
# 30            log_coleman_liau_index
# 31       automated_readability_index
# 32   log_automated_readability_index
# 33                               aer
# 34                               ecm
# 35                               jpe
# 36                               qje
# 37                               res
# 38                         coauthors
# 39                     single_author
# 40                      both_genders
# 41                      only_females
# 42                        only_males
# 43                     num_sentences
# 44                     num_syllables
# 45                   jelcodes_letter
# 46                     jelcodes_text
# 47                             a_imp
# 48                             b_imp
# 49                             c_imp
# 50                             d_imp
# 51                             e_imp
# 52                             f_imp
# 53                             g_imp
# 54                             h_imp
# 55                             i_imp
# 56                             j_imp
# 57                             k_imp
# 58                             l_imp
# 59                             m_imp
# 60                             n_imp
# 61                             o_imp
# 62                             p_imp
# 63                             q_imp
# 64                             r_imp
# 65                             y_imp
# 66                             z_imp
# 67                              tags
# 68                          jel_flag
# 69                     log_num_pages
# 70                     log_num_words
# 71                   log_num_authors
# 72                 log_num_sentences
# 73                 log_num_syllables
# 74                       aer_fkgrade
# 75                       ecm_fkgrade
# 76                       jpe_fkgrade
# 77                       qje_fkgrade
# 78                       res_fkgrade
# 79                          aer_dale
# 80                          ecm_dale
# 81                          jpe_dale
# 82                          qje_dale
# 83                          res_dale
# 84                             a_obs
# 85                             b_obs
# 86                             c_obs
# 87                             d_obs
# 88                             e_obs
# 89                             f_obs
# 90                             g_obs
# 91                             h_obs
# 92                             i_obs
# 93                             j_obs
# 94                             k_obs
# 95                             l_obs
# 96                             m_obs
# 97                             n_obs
# 98                             o_obs
# 99                             p_obs
# 100                            q_obs
# 101                            r_obs
# 102                            y_obs
# 103                            z_obs
# 104                           single
# 105                         isolated
# 106                          cluster
# 107                   length_cluster
#
#                                                             Variable Label
# 0                                                       Title of the paper
# 1                                         Unique identifier for each paper
# 2                                    Journal where the paper was published
# 3                Journal code. [1] AER, [2] ECM, [3] JPE, [4] QJE, [5] RES
# 4                                          Year of the article publication
# 5                                         Month of the article publication
# 6                 Volume of the journal in which the article was published
# 7                  Issue of the journal in which the article was published
# 8                         JEL classification codes assigned by the authors
# 9                        Keywords specified by the authors for the article
# 10                                                 Abstract of the article
# 11                                            Starting page of the article
# 12                                              Ending page of the article
# 13                                         Number of words in the abstract
# 14                                   Indicator for the abstract > 90 words
# 15                                     Unique identifier for the author(s)
# 16                                                Name(s) of the author(s)
# 17                                   Proportion of women among the authors
# 18                                                 Total number of authors
# 19                                     only_male, only_female, both-gender
# 20   Indicates whether the article was authored solely or in collaboration
# 21                                    Total number of pages of the article
# 22         Number of pages normalized (demeaned) based on the dataset mean
# 23            Flesch-Kincaid grade level readability score for the article
# 24           Logarithm of the Flesch-Kincaid grade level readability score
# 25                                       Flesch-Kincaid reading ease score
# 26                      Logarithm of the Flesch-Kincaid reading ease score
# 27                            Dale-Chall readability score for the article
# 28                           Logarithm of the Dale-Chall readability score
# 29                          Coleman-Liau readability index for the article
# 30                         Logarithm of the Coleman-Liau readability index
# 31                       Automated readability index score for the article
# 32                            Logarithm of the automated readability index
# 33                                           Indicator if published in AER
# 34                                           Indicator if published in ECM
# 35                                           Indicator if published in JPE
# 36                                           Indicator if published in QJE
# 37                                           Indicator if published in RES
# 38                                    Indicates the presence of co-authors
# 39                                Indicator if article has a single author
# 40                          Indicator if author team includes both genders
# 41                       Indicator if author team consists only of females
# 42                         Indicator if author team consists only of males
# 43                           Number of sentences in the article's abstract
# 44                           Number of syllables in the article's abstract
# 45          First letter of the JEL classification assigned by the authors
# 46             Full text of the JEL classification assigned by the authors
# 47                                 Indicator if JEL category A was imputed
# 48                                 Indicator if JEL category B was imputed
# 49                                 Indicator if JEL category C was imputed
# 50                                 Indicator if JEL category D was imputed
# 51                                 Indicator if JEL category R was imputed
# 52                                 Indicator if JEL category F was imputed
# 53                                 Indicator if JEL category G was imputed
# 54                                 Indicator if JEL category H was imputed
# 55                                 Indicator if JEL category I was imputed
# 56                                 Indicator if JEL category J was imputed
# 57                                 Indicator if JEL category K was imputed
# 58                                 Indicator if JEL category L was imputed
# 59                                 Indicator if JEL category M was imputed
# 60                                 Indicator if JEL category N was imputed
# 61                                 Indicator if JEL category O was imputed
# 62                                 Indicator if JEL category P was imputed
# 63                                 Indicator if JEL category Q was imputed
# 64                                 Indicator if JEL category R was imputed
# 65                                 Indicator if JEL category Y was imputed
# 66                                 Indicator if JEL category Z was imputed
# 67                     All JEL codes for the article (observed or imputed)
# 68          Indicator of whether the article includes a JEL classification
# 69                                        Logarithm of the number of pages
# 70                        Logarithm of the number of words in the abstract
# 71                                      Logarithm of the number of authors
# 72                    Logarithm of the number of sentences in the abstract
# 73                    Logarithm of the number of syllables in the abstract
# 74            Flesch-Kincaid grade level for articles published in the AER
# 75                Flesch-Kincaid grade level for articles published in ECM
# 76            Flesch-Kincaid grade level for articles published in the JPE
# 77            Flesch-Kincaid grade level for articles published in the QJE
# 78            Flesch-Kincaid grade level for articles published in the RES
# 79                      Dale-Chall score for articles published in the AER
# 80                          Dale-Chall score for articles published in ECM
# 81                      Dale-Chall score for articles published in the JPE
# 82                      Dale-Chall score for articles published in the QJE
# 83                      Dale-Chall score for articles published in the RES
# 84                                          Indicator if JEL category is A
# 85                                          Indicator if JEL category is B
# 86                                          Indicator if JEL category is C
# 87                                          Indicator if JEL category is D
# 88                                          Indicator if JEL category is E
# 89                                          Indicator if JEL category is F
# 90                                          Indicator if JEL category is G
# 91                                          Indicator if JEL category is H
# 92                                          Indicator if JEL category is I
# 93                                          Indicator if JEL category is J
# 94                                          Indicator if JEL category is K
# 95                                          Indicator if JEL category is L
# 96                                          Indicator if JEL category is M
# 97                                          Indicator if JEL category is N
# 98                                          Indicator if JEL category is O
# 99                                          Indicator if JEL category is P
# 100                                         Indicator if JEL category is Q
# 101                                         Indicator if JEL category is R
# 102                                         Indicator if JEL category is Y
# 103                                         Indicator if JEL category is Z
# 104                                 Indicator for single-authored articles
# 105           Indicator for whether the article is isolated in the dataset
# 106                                    Identifier for clusters of articles
# 107                                          Length or size of the cluster

# %% [markdown]
# ## Flesch Reading Ease

# %% [markdown]
# These readability tests are used extensively in the field of education. The "Flesch–Kincaid Grade Level Formula" presents a score as a U.S. grade level, making it easier for teachers, parents, librarians, and others to judge the readability level of various books and texts. It can also mean the number of years of education generally required to understand this text, relevant when the formula results in a number greater than 10. The grade level is calculated with the following formula:
#
# $$
# 0.39\left(\frac{\text { total words }}{\text { total sentences }}\right)+11.8\left(\frac{\text { total syllables }}{\text { total words }}\right)-15.59
# $$
#
# The result is a number that corresponds with a U.S. grade level.
#
# * The lowest grade level score in theory is −3.40.
# * Due to the formula's construction, the score does not have an upper bound.
#
#
#
# Source: [https://en.wikipedia.org/wiki/Flesch-Kincaid_readability_tests](https://en.wikipedia.org/wiki/Flesch-Kincaid_readability_tests)

# %%
# Define the list of variables (columns) to include
columns_of_interest = [
    "log_flesch_kincaid_grade_level", "log_num_authors", "log_num_pages",
    "both_genders", "prop_women", "journal", "jelcodes", "year", "cluster", "jel_flag"
]

# Check if all the columns exist in the DataFrame
missing_columns = [col for col in columns_of_interest if col not in datos.columns]
if missing_columns:
    print(f"The following columns are missing from the DataFrame: {missing_columns}")
else:
    # Select the specified columns and sample 5 random rows
    random_rows = datos[columns_of_interest].sample(n=5, random_state=542)

    # Print the result
    print(random_rows)
# Out:
#       log_flesch_kincaid_grade_level  log_num_authors  log_num_pages  \
# 4707                        2.525838         0.000000       3.433987
# 3807                        2.908348         1.098612       3.784190
# 4579                        2.359175         1.098612       3.401197
# 4551                        2.884002         0.693147       2.484907
# 101                         2.850737         0.693147       2.944439
#
#       both_genders  prop_women                             journal  \
# 4707             0    0.000000      The Review of Economic Studies
# 3807             0    0.000000  The Quarterly Journal of Economics
# 4579             1    0.666667      The Review of Economic Studies
# 4551             0    0.000000      The Review of Economic Studies
# 101              0    0.000000            American Economic Review
#
#                  jelcodes  year  cluster  jel_flag
# 4707                   J1  2015        1         1
# 3807  D61;D62;D84;G12;G14  2014        1         1
# 4579          J64;K14;K42  2012        1         1
# 4551                       2012       80         0
# 101                O0| H1  2002        1         1
